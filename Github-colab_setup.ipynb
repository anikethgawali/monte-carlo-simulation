# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
# !git init monte-carlo-simulation
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/monte-carlo-simulation/.git/

# %%
# %cd monte-carlo-simulation/
# Out:
# /content/drive/MyDrive/Github/monte-carlo-simulation

# %%
# Out:
# /content/drive/MyDrive

# %%
ll
# Out:
# total 3120
# -rw------- 1 root 187108 Jul  8  2022 'Aniiket Gawali Resume.pdf'
# -rw------- 1 root  78129 Aug  1  2021 'Aniket Gawali_Cover Letter GA.pdf'
# -rw------- 1 root 161514 Aug  1  2021 'Aniket Gawali_CV.pdf'
# -rw------- 1 root 107150 Sep 17 15:48 'Aniket Gawali Resume.pdf'
# drwx------ 2 root   4096 Apr 19  2022  Bhavya/
# -rw------- 1 root  37222 Jan 18  2022 'CALENDAR S 22.xlsx'
# drwx------ 2 root   4096 Nov 22  2021 'Colab Notebooks'/
# -rw------- 1 root 505170 Aug 11 02:45  F-1-CPT-Employer-Form_Current.pdf
# -rw------- 1 root 220353 Aug 11 02:42 'F-1-CPT-Student-Form-Current signed.pdf'
# -rw------- 1 root 977861 Aug 11 02:56 'Gawali_Aniket Harishchandra CPT Fall 22.pdf'
# -rw------- 1 root 583281 Jan 13 21:24 'Gawali_Aniket Harishchandra CPT Spring 23.pdf'
# drwx------ 3 root   4096 Feb  6 18:48  Github/
# -rw------- 1 root    171 Sep  7 05:14 'Master CF Company List (2) (1).gdoc'
# -rw------- 1 root    171 Sep  7 05:14 'Master CF Company List (2).gdoc'
# ...

# %%
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
